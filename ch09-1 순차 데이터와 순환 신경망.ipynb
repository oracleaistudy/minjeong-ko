# %% [markdown]
# #### 순차데이터
# - 텍스트나 시계열 데이터와 같이 순서에 의미가 있는 데이터
# - 순차 데이터를 다룰 때는 이전에 입력한 데이터를 기억하는 기능 필요
#
# ex) “별로지만 추천해요”에서 “추천해요”가 입력될 때 “별로지만”을 기억하고 있어야 이 댓글을 무조건 긍정적이라고 판단하지 않을 것
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 피드포워드 신경망
# - 입력 데이터의 흐름이 앞으로만 전달되는 신경망
# - 완전 연결 신경망과 합성곱 신경망
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 순환 신경망
# - 순차 데이터에 잘 맞는 인공 신경망의 한 종류
# - 완전 연결 신경망에 이전 데이터의 처리 결과가 순환되는 고리 하나만 추가
# - 셀의 출력(은닉 상태)을 다음 타임 스텝에 재사용
#
# ![image-3.png](attachment:image-3.png)
#
# 타임스텝 : 샘플을 처리하는 한 단계
# - 순환 신경망에서는 층을 셀이라고 부름
# - 하나의 셀은 여러 개의 뉴런으로 구성 됨
# - 순환 신경망은 이전 타임 스텝의 샘플을 기억하지만 타임스텝이 오래될수록 순환되는 정보는 희미해짐
#
# ![image.png](attachment:image.png)
#
# ![image-4.png](attachment:image-4.png)
#
# tanh
# - 일반적으로 은닉층의 활성화 함수로는 하이퍼볼릭 탄젠트 함수인 tanh가 많이 사용됨
# - tanh 함수도 S자 모양을 띠기 때문에 종종 시그모이드 함수라고 부르기도 하지만 시그모이드 함수와 달리 -1 ~ 1 사이의 범위를 가짐
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 순환층의 입력과 출력
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
